# %%
from pathlib import Path
import numpy as np
import plotly.graph_objects as go

npz_path = Path('/home/exx/Downloads/embedding_goal.npz') ## CHANGE THE PATH
point_data = np.load(npz_path, allow_pickle = True)
sim = point_data['points_colors']
# sim = point_data
print(sim.shape) # sim (num_points,6)
sim_points = sim[:,:3]
sim_colors = sim[:,3:]

skip = 1
go_data=[
    go.Scatter3d(x=sim_points[::skip,0], y=sim_points[::skip,1], z=sim_points[::skip,2], 
                 mode='markers', marker=dict(size=1, color=sim_colors,
                 symbol='circle')),
]
layout = go.Layout(
    scene=dict(
        aspectmode='data'
    )
)

fig = go.Figure(data=go_data, layout=layout)
fig.update_layout(scene = dict(
                                    xaxis = dict(
                                         backgroundcolor="rgba(0, 0, 0,0)",
                                         gridcolor="white",
                                         showbackground=True,
                                         zerolinecolor="white",
                                        showticklabels = False),
                                    yaxis = dict(
                                        backgroundcolor="rgba(0, 0, 0,0)",
                                        gridcolor="white",
                                        showbackground=True,
                                        zerolinecolor="white",
                                    showticklabels = False),
                                    zaxis = dict(
                                        backgroundcolor="rgba(0, 0, 0,0)",
                                        gridcolor="white",
                                        showbackground=True,
                                        zerolinecolor="white",
                                    showticklabels = False),),
                     )
fig.show()
# Out:
# (2000, 6)
# <div>                            <div id="691033fa-a90b-4eb0-bb98-05754c0746ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("691033fa-a90b-4eb0-bb98-05754c0746ae")) {                    Plotly.newPlot(                        "691033fa-a90b-4eb0-bb98-05754c0746ae",                        [{"marker":{"color":[[127.5,226.65081787109375,207.07949829101562],[243.35789489746094,127.5,167.85678100585938],[219.35939025878906,127.5,215.9200439453125],[186.3766326904297,127.5,174.22695922851562],[127.5,249.276123046875,165.27333068847656],[127.5,255.0,127.5],[127.5,252.4515380859375,136.28285217285156],[127.5,255.0,127.5],[127.5,208.18116760253906,226.2258758544922],[127.5,255.0,127.5],[195.7430877685547,127.5,204.79718017578125],[127.5,255.0,127.5],[238.44383239746094,127.5,190.33087158203125],[127.5,255.0,127.5],[127.5,127.5,240.9009552001953],[127.5,142.98541259765625,210.58697509765625],[127.5,255.0,127.5],[229.6367950439453,127.5,203.81724548339844],[127.5,255.0,127.5],[127.5,255.0,127.5],[167.0632781982422,141.41758728027344,247.90472412109375],[236.34420776367188,127.5,162.28819274902344],[142.82418823242188,145.1795196533203,209.18386840820312],[205.96524047851562,133.19326782226562,227.83465576171875],[127.5,255.0,127.5],[127.5,249.7653350830078,163.65846252441406],[127.5,255.0,127.5],[127.5,254.78359985351562,127.5],[213.99331665039062,127.5,171.68719482421875],[127.5,255.0,127.5],[127.5,216.5210418701172,218.7483367919922],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,252.43283081054688,152.95660400390625],[127.5,255.0,127.5],[236.46080017089844,127.5,193.71026611328125],[240.23916625976562,127.5,176.47366333007812],[127.5,255.0,127.5],[127.5,255.0,127.5],[225.9918670654297,127.5,208.46665954589844],[127.5,255.0,127.5],[242.7464141845703,127.5,182.03912353515625],[207.20986938476562,159.917724609375,221.58334350585938],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,174.58787536621094,177.3981170654297],[127.5,255.0,127.5],[153.7705841064453,127.5,190.58909606933594],[127.5,255.0,127.5],[127.5,240.3134765625,186.90847778320312],[127.5,154.26828002929688,243.39280700683594],[127.5,255.0,127.5],[176.81918334960938,127.5,196.029541015625],[127.5,255.0,127.5],[127.5,250.19989013671875,162.15524291992188],[213.5528106689453,127.5,217.29769897460938],[127.5,127.5,255.0],[127.5,136.562255859375,254.4742431640625],[127.5,162.6346435546875,220.27011108398438],[127.5,255.0,127.5],[169.63446044921875,143.1390838623047,198.24407958984375],[127.5,255.0,127.5],[127.5,238.3609619140625,190.4769744873047],[127.5,255.0,127.5],[210.35968017578125,127.5,224.32293701171875],[127.5,255.0,127.5],[241.64151000976562,127.5,184.31517028808594],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,204.11888122558594,218.11131286621094],[143.9335174560547,155.37319946289062,250.8258819580078],[127.5,211.02748107910156,210.2281951904297],[226.56301879882812,127.5,179.79173278808594],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,175.67709350585938,226.2808380126953],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,255.0,127.5],[240.88629150390625,127.5,162.0476837158203],[232.55535888671875,127.5,199.7469482421875],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,255.0,127.5],[127.5,255.0,127.5],[242.25335693359375,127.5,183.0690460205078],[211.8064727783203,127.5,223.148681640625],[136.43896484375,127.5,199.8570556640625],[127.5,135.31187438964844,212.97756958007812],[224.85723876953125,127.5,209.82749938964844],[194.01974487304688,127.5,201.5282440185547],[197.79808044433594,127.5,185.9757537841797],[127.5,255.0,127.5],[242.98793029785156,127.5,181.5258026123047],[127.5,243.01651000976562,181.46469116210938],[127.5,254.9918670654297,128.94020080566406],[127.5,255.0,127.5],[127.5,255.0, ...

# %%
from pathlib import Path
import numpy as np
import plotly.graph_objects as go

npz_path = Path('/home/exx/Downloads/embedding/points_colors.npy') ## CHANGE THE PATH
point_data = np.load(npz_path, allow_pickle = True)
# sim = point_data['points_colors']
sim = point_data
print(sim.shape) # sim (num_points,6)
sim_points = sim[:,:3]
sim_colors = sim[:,3:]

skip = 1
go_data=[
    go.Scatter3d(x=sim_points[::skip,0], y=sim_points[::skip,1], z=sim_points[::skip,2], 
                 mode='markers', marker=dict(size=1, color=sim_colors,
                 symbol='circle')),
]
layout = go.Layout(
    scene=dict(
        aspectmode='data'
    )
)

fig = go.Figure(data=go_data, layout=layout)
fig.update_layout(scene = dict(
                                    xaxis = dict(
                                         backgroundcolor="rgba(0, 0, 0,0)",
                                         gridcolor="white",
                                         showbackground=True,
                                         zerolinecolor="white",
                                        showticklabels = False),
                                    yaxis = dict(
                                        backgroundcolor="rgba(0, 0, 0,0)",
                                        gridcolor="white",
                                        showbackground=True,
                                        zerolinecolor="white",
                                    showticklabels = False),
                                    zaxis = dict(
                                        backgroundcolor="rgba(0, 0, 0,0)",
                                        gridcolor="white",
                                        showbackground=True,
                                        zerolinecolor="white",
                                    showticklabels = False),),
                     )
fig.show()
# Out:
# (2000, 6)
# <div>                            <div id="3328f532-9d92-44cb-96f4-74b6b28219d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("